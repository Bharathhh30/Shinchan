# %% [markdown]
# Pandas

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('onlinefoods.csv')
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
df.Age.value_counts()
# Out:
# Age
# 23    73
# 22    57
# 25    52
# 24    50
# 26    35
# 21    23
# 27    21
# 32    16
# 28    15
# 29    14
# 20     9
# 30     9
# 31     8
# 19     4
# 18     1
# 33     1
# Name: count, dtype: int64

# %%
mean=df.Age.mean()
df.Age.map(lambda x : x- mean)
# Out:
# 0     -4.628866
# 1     -0.628866
# 2     -2.628866
# 3     -2.628866
# 4     -2.628866
#          ...
# 383   -1.628866
# 384   -1.628866
# 385   -2.628866
# 386   -1.628866
# 387   -1.628866
# Name: Age, Length: 388, dtype: float64

# %%
df.Age.unique()
# Out:
# array([20, 24, 22, 27, 23, 21, 28, 25, 32, 30, 31, 26, 18, 19, 33, 29],
#       dtype=int64)

# %%
b=df.loc[[0,1,10,100],['Age','Gender','Occupation']]
b
# Out:
#      Age  Gender Occupation
# 0     20  Female    Student
# 1     24  Female    Student
# 10    22  Female    Student
# 100   24  Female    Student

# %%
df['My Col']=range(len(df),0,-1)
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
a=df.loc[(df.Age == 22) | (df.Occupation == "Student")]
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 216 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         216 non-null    int64
#  1   Gender                      216 non-null    object
#  2   Marital Status              216 non-null    object
#  3   Occupation                  216 non-null    object
#  4   Monthly Income              216 non-null    object
#  5   Educational Qualifications  216 non-null    object
#  6   Family size                 216 non-null    int64
#  7   latitude                    216 non-null    float64
#  8   longitude                   216 non-null    float64
#  9   Pin code                    216 non-null    int64
#  10  Output                      216 non-null    object
#  11  Feedback                    216 non-null    object
#  12  Unnamed: 12                 216 non-null    object
# ...

# %%
a=df.loc[df.Age.isin([22,24])]
a.loc[a.Age.notnull()]
# a.Age == 20
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# 6     22    Male         Single    Student       No Income
# ..   ...     ...            ...        ...             ...
# 370   22  Female         Single    Student       No Income
# 379   22    Male         Single    Student  Below Rs.10000
# 381   22    Male         Single    Student       No Income
# 382   24  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 1                     Graduate            3   12.9770    77.5773    560009
# 2                Post Graduate            3   12.9551    77.6593    560017
# ...

# %% [markdown]
# iloc uses the Python stdlib indexing scheme, where the first element of the range is included
# and the last one excluded. So 0:10 will select entries 0,...,9. loc, meanwhile, indexes inclusively. So 0:10 will select entries 0,...,10.

# %%
df.iloc[0:3,0]
# Out:
# 0    20
# 1    24
# 2    22
# Name: Age, dtype: int64

# %%
df.loc[0:3,'Age']
# in loc last value is also inclusive and consider , but in iloc the last value is not considered (made exclusive)
# Out:
# 0    20
# 1    24
# 2    22
# 3    22
# Name: Age, dtype: int64

# %% [markdown]
# This is particularly confusing when the DataFrame index is a simple numerical list, e.g. 0,...,1000. In this case df.iloc[0:1000] will return 1000 entries, while df.loc[0:1000] return 1001 of them! To get 1000 elements using loc, you will need to go one lower and ask for df.loc[0:999].

# %%
# df.set_index('Age')
df
# Out:
#      Gender Marital Status Occupation  Monthly Income  \
# Age
# 20   Female         Single    Student       No Income
# 24   Female         Single    Student  Below Rs.10000
# 22     Male         Single    Student  Below Rs.10000
# 22   Female         Single    Student       No Income
# 22     Male         Single    Student  Below Rs.10000
# ..      ...            ...        ...             ...
# 23   Female         Single    Student       No Income
# 23   Female         Single    Student       No Income
# 22   Female         Single    Student       No Income
# 23     Male         Single    Student  Below Rs.10000
# 23     Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# Age
# 20               Post Graduate            4   12.9766    77.5993    560001
# 24                    Graduate            3   12.9770    77.5773    560009
# 22               Post Graduate            3   12.9551    77.6593    560017
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         388 non-null    int64
#  1   Gender                      388 non-null    object
#  2   Marital Status              388 non-null    object
#  3   Occupation                  388 non-null    object
#  4   Monthly Income              388 non-null    object
#  5   Educational Qualifications  388 non-null    object
#  6   Family size                 388 non-null    int64
#  7   latitude                    388 non-null    float64
#  8   longitude                   388 non-null    float64
#  9   Pin code                    388 non-null    int64
#  10  Output                      388 non-null    object
#  11  Feedback                    388 non-null    object
#  12  Unnamed: 12                 388 non-null    object
# ...

# %%
df.describe()
# only integer and float datatype columns will be taken into consideration for calculation , object data type columns wont be taken into consideration
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  388.000000   388.000000  388.000000  388.000000     388.000000
# mean    24.628866     3.280928   12.972058   77.600160  560040.113402
# std      2.975593     1.351025    0.044489    0.051354      31.399609
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     23.000000     2.000000   12.936900   77.565275  560010.750000
# 50%     24.000000     3.000000   12.977000   77.592100  560033.500000
# 75%     26.000000     4.000000   12.997025   77.630900  560068.000000
# max     33.000000     6.000000   13.102000   77.758200  560109.000000

# %%
df['Age'].value_counts()
# Out:
# Age
# 23    73
# 22    57
# 25    52
# 24    50
# 26    35
# 21    23
# 27    21
# 32    16
# 28    15
# 29    14
# 20     9
# 30     9
# 31     8
# 19     4
# 18     1
# 33     1
# Name: count, dtype: int64

# %%
df[df['Age']<25].describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  217.000000   217.000000  217.000000  217.000000     217.000000
# mean    22.534562     3.193548   12.972808   77.594511  560037.663594
# std      1.220941     1.232039    0.043727    0.046998      31.401849
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     22.000000     2.000000   12.943800   77.571300  560010.000000
# 50%     23.000000     3.000000   12.977000   77.586400  560027.000000
# 75%     23.000000     4.000000   12.992500   77.613100  560066.000000
# max     24.000000     6.000000   13.102000   77.758200  560109.000000

# %%
test_df=pd.read_csv('Test1.csv',sep=";")

# %%
df.to_csv('Converted.csv')

# %%
test_df.head()
# Out:
#   Unnamed: 0  column1  column2  column3  column4
# 0       row1      0.0      1.0      2.0      3.0
# 1        row      4.0      5.0      6.0      7.0
# 2       row3      8.0      9.0     10.0     11.0
# 3       row4     12.0     13.0     14.0     15.0
# 4       row5     16.0     17.0     18.0     19.0

# %%
from io import StringIO,BytesIO

# %%
data=('col1,col2,col3\n'
      'x,y,1\n'
      'a,b,2\n'
      'c,d,3')

# %%
print(data)
# Out:
# col1,col2,col3
# x,y,1
# a,b,2
# c,d,3

# %%
type(data)
# Out:
# str

# %%
a=pd.read_csv(StringIO(data),dtype={'col1':object,'col3':float})

# %%
a
# Out:
#   col1 col2  col3
# 0    x    y   1.0
# 1    a    b   2.0
# 2    c    d   3.0

# %%
a1=
# Out:
#   col1 col2  col3
# 0    x    y   1.0
# 1    a    b   2.0
# 2    c    d   3.0

# %%
df.dtypes
# Out:
# Age                             int64
# Gender                         object
# Marital Status                 object
# Occupation                     object
# Monthly Income                 object
# Educational Qualifications     object
# Family size                     int64
# latitude                      float64
# longitude                     float64
# Pin code                        int64
# Output                         object
# Feedback                       object
# Unnamed: 12                    object
# dtype: object

# %%
data=('index,a,b,c\n'
      '4,apple,bat,5.7\n'
      '8,orange,cow,10')

# %%
pd.read_csv(StringIO(data))
# Out:
#    index       a    b     c
# 0      4   apple  bat   5.7
# 1      8  orange  cow  10.0

# %%
pd.read_csv(StringIO(data),index_col=0)
# Out:
#             a    b     c
# index
# 4       apple  bat   5.7
# 8      orange  cow  10.0

# %%
data=('a,b,c,d\n'
      '4,apple,bat\n'
      '8,orange,cow')

# %%
pd.read_csv(StringIO(data),usecols=['b','c'],index_col=1)
# Out:
#           b
# c
# bat   apple
# cow  orange

# %%
data = 'a,b\n"hello, \\"Bob\\", nice to see you",5'

# %%
pd.read_csv(StringIO(data),escapechar='\\')5
# Out:
#                                a  b
# 0  hello, "Bob", nice to see you  5

# %% [markdown]
# Read Json to CSV

# %%
Data = '{"employee_name": "James", "email": "james@gmail.com", "job_profile": [{"title1":"Team Lead", "title2":"Sr. Developer"}]}'
df1=pd.read_json(Data)

# %%
df1
# Out:
#   employee_name            email  \
# 0         James  james@gmail.com
#
#                                          job_profile
# 0  {'title1': 'Team Lead', 'title2': 'Sr. Develop...

# %%
# converting json to different json formats
# df1.to_json()
df1.to_json(orient='records')
# Out:
# '[{"employee_name":"James","email":"james@gmail.com","job_profile":{"title1":"Team Lead","title2":"Sr. Developer"}}]'

# %%
df=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data')

# %%
df.to_csv('wine.csv')

# %%
df.to_json

# %%
df.to_json('hi.json')

# %% [markdown]
# Reading HTML Content

# %%
pip install html5lib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install BeautifulSoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
url = 'https://en.wikipedia.org/wiki/Mobile_country_code'
dfs = pd.read_html(url,match=)

# %%
# type(dfs)
dfs[0]
# Out:
#      Mobile country code                                    Country ISO 3166  \
# 0                    289                                 A Abkhazia    GE-AB
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
# ...

# %% [markdown]
# Reading EXcel Files

# %%
df_excel=pd.read_excel("Certifications.xlsx")

# %%
df_excel
# Out:
#    Unnamed: 0              Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         NaN                     NaN         NaN        NaN        NaN
# 1         NaN                     NaN         NaN        NaN        NaN
# 2         NaN                     NaN         NaN        NaN        NaN
# 3         NaN                     NaN         NaN        NaN        NaN
# 4         NaN                     NaN         NaN        NaN        NaN
# ..        ...                     ...         ...        ...        ...
# 69         62  Thakkalapalli Sai Teja  23EG110A62       2023       DS-a
# 70         63                     NaN         NaN        NaN        NaN
# 71         64                     NaN         NaN        NaN        NaN
# 72         65            V.SAI SRIMAN  23EG110A65   1st year       DS-A
# 73         66        Vinukonda Jyothi  23EG110A66          1       DS-A
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 59  \
# ...

# %%
df_excel.to_pickle('pickle_file')

# %%
data = [[2, 'Meir', 3000], [3, 'Michael', 3800], [7, 'Addilyn', 7400], [8, 'Juan', 6100], [9, 'Kannon', 7700]]
employees = pd.DataFrame(data, columns=['employee_id', 'name', 'salary']).astype({'employee_id':'int64', 'name':'object', 'salary':'int64'})

# %%
filter_data=employees['name'].str.startswith("M")

# %%
final_data=employees[filter_data]

# %%
final_data
# Out:
#    employee_id     name  salary
# 0            2     Meir    3000
# 1            3  Michael    3800

# %%
filtered_employees = employees.loc[employees['name'].str.startswith("M"),["name"]]

# %%
filtered_employees
# Out:
#       name
# 0     Meir
# 1  Michael

# %%
result = filtered_employees[['employee_id', 'salary']]
print(result)
# Out:
#    employee_id  salary
# 0            2    3000
# 1            3    3800

# %%
fruits_dict = {"Apples": [30], "Bananas": [21]}
fruits_df = pd.DataFrame(fruits_dict)  # Optional: Add index if needed

print(fruits_df)
# Out:
#    Apples  Bananas
# 0      30       21
